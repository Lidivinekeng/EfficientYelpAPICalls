# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
# os - for saving and loading files
# json - to work with json files
# math - to round up results
# time - to add a short pause to not overwhelm the server
import os, json, math, time

# to make yelpapi calls
from yelpapi import YelpAPI

# progress bar from tqdm_notebook
from tqdm.notebook import tqdm_notebook

# %%
# !pip install yelpapi
# !pip install tqdm
# Out:
# Requirement already satisfied: yelpapi in c:\users\lidiv\anaconda3\lib\site-packages (2.5.0)
# Requirement already satisfied: requests in c:\users\lidiv\anaconda3\lib\site-packages (from yelpapi) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lidiv\anaconda3\lib\site-packages (from requests->yelpapi) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lidiv\anaconda3\lib\site-packages (from requests->yelpapi) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lidiv\anaconda3\lib\site-packages (from requests->yelpapi) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lidiv\anaconda3\lib\site-packages (from requests->yelpapi) (2023.7.22)
# Requirement already satisfied: tqdm in c:\users\lidiv\anaconda3\lib\site-packages (4.65.0)
# Requirement already satisfied: colorama in c:\users\lidiv\anaconda3\lib\site-packages (from tqdm) (0.4.6)

# %%
import json
with open('/Users/lidiv/.secret/yelp_api.json') as f: #change the path to match YOUR path!!
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'], timeout_s = 5.0)

# %%
# set our API call parameters and filename before the first call
location = 'San antonio, TX '
term = 'fried rice'

# %%
## Specify folder for saving data
FOLDER = 'Data/'

os.makedirs(FOLDER, exist_ok = True)
# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location}.json"

# %%
JSON_FILE
# Out:
# 'Data/San antonio, TX .json'

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)

## If it does not exist: 
if file_exists == False:    
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON folder name is not empty:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")

    
    ## save the first page of results
    with open(JSON_FILE, 'w') as f:
          json.dump([], f)
        
## If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/San antonio, TX .json not found. Saving empty list to file.

# %%
os.path.isfile(JSON_FILE)
# Out:
# True

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term = term, location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 497

# %%
results['region']
# Out:
# {'center': {'longitude': -98.514404296875, 'latitude': 29.494438307483204}}

# %%
results['businesses']
# Out:
# [{'id': 'zA74m8K0IYQMT4FfthcUGw',
#   'alias': 'sichuan-house-san-antonio',
#   'name': 'Sichuan House',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ag1Cipfsn-LE-1_SJmgO0Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sichuan-house-san-antonio?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 1038,
#   'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.471805, 'longitude': -98.623466},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '3505 Wurzbach Rd',
#    'address2': 'Ste 103',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78238',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3505 Wurzbach Rd',
#     'Ste 103',
#     'San Antonio, TX 78238']},
#   'phone': '+12105099999',
#   'display_phone': '(210) 509-9999',
#   'distance': 10858.68824399154},
#  {'id': 'SqhBl2SvdGzRbWTiCMKR4A',
#   'alias': 'noods-san-antonio-4',
#   'name': 'Noods',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3AZnMJ7ede-NAz-joPteqQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/noods-san-antonio-4?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 7,
#   'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.44196636184658, 'longitude': -98.5105752},
#   'transactions': [],
#   'location': {'address1': '427 Lombrano St',
#    'address2': None,
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78207',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['427 Lombrano St', 'San Antonio, TX 78207']},
#   'phone': '+12104800561',
#   'display_phone': '(210) 480-0561',
#   'distance': 5846.371497848622},
#  {'id': 'hKSwFoVXwr9SpeiH6Na29A',
#   'alias': 'tiger-s-chinese-cuisine-san-antonio',
#   'name': 'Tiger’s Chinese Cuisine',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/onJixHJdLYGhMQjxaZ0jFQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tiger-s-chinese-cuisine-san-antonio?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 126,
#   'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.56257943164515,
#    'longitude': -98.5930831670598},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '12730 W I-10 Frontage Rd',
#    'address2': 'Ste 312',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78230',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['12730 W I-10 Frontage Rd',
#     'Ste 312',
#     'San Antonio, TX 78230']},
#   'phone': '+12105385080',
#   'display_phone': '(210) 538-5080',
#   'distance': 10740.456559488077},
#  {'id': 'HNOz4-MhYCWNX2ik9UqYQw',
#   'alias': 't-jins-china-diner-san-antonio',
#   'name': "T Jin's China Diner",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MdxNjMsYyVPk07O_3eneIw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/t-jins-china-diner-san-antonio?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 412,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.6388, 'longitude': -98.45705},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '20835 US-281 N',
#    'address2': 'Ste 502',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78258',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['20835 US-281 N', 'Ste 502', 'San Antonio, TX 78258']},
#   'phone': '+12105457777',
#   'display_phone': '(210) 545-7777',
#   'distance': 16984.558552045506},
#  {'id': 'vCXT8MFy4U8pW0ZmgoM9Xg',
#   'alias': 'tongs-thai-restaurant-san-antonio',
#   'name': "Tong's Thai Restaurant",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QASd7c_7kdzdHti6U-XDdg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tongs-thai-restaurant-san-antonio?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 852,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.4867884, 'longitude': -98.448251},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1146 Austin Hwy',
#    'address2': '',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78209',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1146 Austin Hwy', 'San Antonio, TX 78209']},
#   'phone': '+12108297345',
#   'display_phone': '(210) 829-7345',
#   'distance': 6469.028248147669},
#  {'id': 'JYA-I2HxlqJxgArkKtSeuw',
#   'alias': 'best-quality-daughter-san-antonio',
#   'name': 'Best Quality Daughter',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8IL8yk306hENoYCpNcEN8A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/best-quality-daughter-san-antonio?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 615,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.44148, 'longitude': -98.479169},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '602 Avenue A',
#    'address2': '',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78215',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['602 Avenue A', 'San Antonio, TX 78215']},
#   'phone': '+12108194236',
#   'display_phone': '(210) 819-4236',
#   'distance': 6806.232817722444},
#  {'id': 'dDxt_fv4627-W-aRKoh1XA',
#   'alias': 'shinko-hibachi-and-boba-tea-san-antonio-4',
#   'name': 'Shinko- Hibachi and Boba Tea',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YuY_UQOXd_jXPzrC5M47KQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shinko-hibachi-and-boba-tea-san-antonio-4?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 65,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.507840031658407,
#    'longitude': -98.62992910241954},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '7531 Bandera Rd',
#    'address2': 'Ste 106',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78238',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['7531 Bandera Rd', 'Ste 106', 'San Antonio, TX 78238']},
#   'phone': '+12102908182',
#   'display_phone': '(210) 290-8182',
#   'distance': 11279.12877063315},
#  {'id': 'AJnKsR-pSqrHLYNE3_VExg',
#   'alias': 'katii-san-antonio',
#   'name': 'Katii',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yaeF9Kk8iYCkCU9Uu60H9A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/katii-san-antonio?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 40,
#   'categories': [{'alias': 'foodtrucks', 'title': 'Food Trucks'},
#    {'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.45053, 'longitude': -98.48654},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': "2710 N St Mary's St",
#    'address2': None,
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78212',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ["2710 N St Mary's St", 'San Antonio, TX 78212']},
#   'phone': '+18302605011',
#   'display_phone': '(830) 260-5011',
#   'distance': 5574.027946346835},
#  {'id': 'Dz08SymMWgE4EegBVMyLMw',
#   'alias': 'bamboo-san-antonio-2',
#   'name': 'Bamboo',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WZ7mdOZV077-fXaBvI-mLw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bamboo-san-antonio-2?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 287,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 29.41374873843138,
#    'longitude': -98.49958544898266},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '1010 S Flores St',
#    'address2': 'Ste 111',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78204',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1010 S Flores St',
#     'Ste 111',
#     'San Antonio, TX 78204']},
#   'phone': '+12104814884',
#   'display_phone': '(210) 481-4884',
#   'distance': 9086.260134816777},
#  {'id': 'RjokTlon6H5ZIM9gkeLXSw',
#   'alias': 'mings-san-antonio',
#   'name': "Ming's",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1LR8cZh-_mqv60eT4oRkyg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mings-san-antonio?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 296,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.440935621594612,
#    'longitude': -98.48531614942613},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '914 E Elmira St',
#    'address2': 'Ste 101',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78212',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['914 E Elmira St', 'Ste 101', 'San Antonio, TX 78212']},
#   'phone': '+12106004083',
#   'display_phone': '(210) 600-4083',
#   'distance': 6582.035890522851},
#  {'id': 'tmg_BwqYvY4uNMppvSUfZg',
#   'alias': 'china-inn-san-antonio',
#   'name': 'China Inn',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/irs8xWuV_VjhQr2QxCD3Bw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-inn-san-antonio?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 411,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.535501215577124,
#    'longitude': -98.52338973503458},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2241 NW Military Hwy',
#    'address2': 'Ste 101',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78213',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2241 NW Military Hwy',
#     'Ste 101',
#     'San Antonio, TX 78213']},
#   'phone': '+12103088277',
#   'display_phone': '(210) 308-8277',
#   'distance': 4648.029204628728},
#  {'id': 'NG7YAcrwhht6-PERQZvtbg',
#   'alias': 'time-to-8-san-antonio',
#   'name': 'Time to 8',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GqwHJ3gftORrQPbg57eSlQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/time-to-8-san-antonio?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 94,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 29.52997, 'longitude': -98.59286},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '9390 Huebner Rd',
#    'address2': 'Ste 104',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78240',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['9390 Huebner Rd', 'Ste 104', 'San Antonio, TX 78240']},
#   'phone': '+17262156688',
#   'display_phone': '(726) 215-6688',
#   'distance': 8561.177724062287},
#  {'id': 'QOSNw732x0Uc-3yM9jOJfg',
#   'alias': 'thai-dee-san-antonio',
#   'name': 'Thai Dee',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nf7-Hx0QytK8m9e04ZhULw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/thai-dee-san-antonio?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 607,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.49933, 'longitude': -98.50813},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '5307 Blanco Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78216',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['5307 Blanco Rd', 'San Antonio, TX 78216']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 811.1996665171681},
#  {'id': 'fGoCRJ3WCQvVktqMhvft6w',
#   'alias': 'sichuan-garden-san-antonio',
#   'name': 'Sichuan Garden',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CSiQvqg0RROE_pNicv6p8A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sichuan-garden-san-antonio?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 448,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.5431364, 'longitude': -98.5285091},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '2347 NW Military Hwy',
#    'address2': '',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78231',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['2347 NW Military Hwy', 'San Antonio, TX 78231']},
#   'phone': '+12102655750',
#   'display_phone': '(210) 265-5750',
#   'distance': 5635.678157110193},
#  {'id': 'woAkGSd5O2JcOyBPlmV8gA',
#   'alias': 'ichiban-steak-and-asian-fusion-san-antonio-2',
#   'name': 'Ichiban Steak & Asian Fusion',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U3068oMzReDHlnlBtt8Jew/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ichiban-steak-and-asian-fusion-san-antonio-2?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 240,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.51995, 'longitude': -98.60434},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '8601 Huebner Rd',
#    'address2': 'Ste 103',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78240',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['8601 Huebner Rd', 'Ste 103', 'San Antonio, TX 78240']},
#   'phone': '+12106411234',
#   'display_phone': '(210) 641-1234',
#   'distance': 9154.664067438891},
#  {'id': 'Ps-zAgPdR2yu8gSXQBnH-A',
#   'alias': 'lucky-noodle-san-antonio-2',
#   'name': 'Lucky Noodle',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qcJTbV1pdy1diftLuvu4pQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lucky-noodle-san-antonio-2?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 578,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.544727, 'longitude': -98.509676},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '8525 Blanco Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78216',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['8525 Blanco Rd', 'San Antonio, TX 78216']},
#   'phone': '+12102365244',
#   'display_phone': '(210) 236-5244',
#   'distance': 5610.526316736753},
#  {'id': 'F4UNv4kqig2z79d321D65Q',
#   'alias': 'formosa-garden-san-antonio',
#   'name': 'Formosa Garden',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y4GlxuhSY5BAeLH5KZN31Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/formosa-garden-san-antonio?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 350,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 29.51696, 'longitude': -98.45801},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1011 NE Interstate 410 Loop',
#    'address2': '',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78209',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1011 NE Interstate 410 Loop',
#     'San Antonio, TX 78209']},
#   'phone': '+12108289988',
#   'display_phone': '(210) 828-9988',
#   'distance': 6008.028225369878},
#  {'id': 'Rw5MRYU_J7Pew033C5_pUg',
#   'alias': 'sukhothai-thai-restaurant-express-san-antonio-5',
#   'name': 'Sukhothai Thai Restaurant Express',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y9Mg-RsMiqYFaetX0NC09Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sukhothai-thai-restaurant-express-san-antonio-5?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 185,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.51146, 'longitude': -98.66207},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '7664 Tezel Rd',
#    'address2': 'Ste 105',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78250',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['7664 Tezel Rd', 'Ste 105', 'San Antonio, TX 78250']},
#   'phone': '+12103141106',
#   'display_phone': '(210) 314-1106',
#   'distance': 14414.0830648538},
#  {'id': 'PyEIPJnZg-Y1NuNlWlsPEw',
#   'alias': 'singhs-san-antonio-2',
#   'name': 'Singhs',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/K-n1sdc49v1wWEqwq5X_dw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/singhs-san-antonio-2?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 305,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.451392717586, 'longitude': -98.4861743822694},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': "2803 N St Mary's St",
#    'address2': '',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78212',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ["2803 N St Mary's St", 'San Antonio, TX 78212']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 5511.644717580751},
#  {'id': 'X6btex-ZPuCq6zi6zKMFZA',
#   'alias': 'wah-kee-chinese-seafood-cuisine-san-antonio',
#   'name': 'Wah Kee Chinese Seafood Cuisine',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/U-yc2qXxJvtpWbFOktvNJA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wah-kee-chinese-seafood-cuisine-san-antonio?adjust_creative=8Kr7BTdHi9CvPNOmnxg5vQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8Kr7BTdHi9CvPNOmnxg5vQ',
#   'review_count': 277,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 29.611186284576338,
#    'longitude': -98.50692009014374},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '18360 Blanco Rd',
#    'address2': 'Ste 122',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78258',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['18360 Blanco Rd', 'Ste 122', 'San Antonio, TX 78258']},
#   'phone': '+12104976669',
#   'display_phone': '(210) 497-6669',
#   'distance': 13001.938041075715}]

# %%
## How many results total?
pd.DataFrame(results['businesses'])
# Out:
#                         id                                            alias  \
# 0   zA74m8K0IYQMT4FfthcUGw                        sichuan-house-san-antonio
# 1   SqhBl2SvdGzRbWTiCMKR4A                              noods-san-antonio-4
# 2   hKSwFoVXwr9SpeiH6Na29A              tiger-s-chinese-cuisine-san-antonio
# 3   HNOz4-MhYCWNX2ik9UqYQw                   t-jins-china-diner-san-antonio
# 4   vCXT8MFy4U8pW0ZmgoM9Xg                tongs-thai-restaurant-san-antonio
# 5   JYA-I2HxlqJxgArkKtSeuw                best-quality-daughter-san-antonio
# 6   dDxt_fv4627-W-aRKoh1XA        shinko-hibachi-and-boba-tea-san-antonio-4
# 7   AJnKsR-pSqrHLYNE3_VExg                                katii-san-antonio
# 8   Dz08SymMWgE4EegBVMyLMw                             bamboo-san-antonio-2
# 9   RjokTlon6H5ZIM9gkeLXSw                                mings-san-antonio
# 10  tmg_BwqYvY4uNMppvSUfZg                            china-inn-san-antonio
# 11  NG7YAcrwhht6-PERQZvtbg                            time-to-8-san-antonio
# 12  QOSNw732x0Uc-3yM9jOJfg                             thai-dee-san-antonio
# 13  fGoCRJ3WCQvVktqMhvft6w                       sichuan-garden-san-antonio
# 14  woAkGSd5O2JcOyBPlmV8gA     ichiban-steak-and-asian-fusion-san-antonio-2
# 15  Ps-zAgPdR2yu8gSXQBnH-A                       lucky-noodle-san-antonio-2
# 16  F4UNv4kqig2z79d321D65Q                       formosa-garden-san-antonio
# 17  Rw5MRYU_J7Pew033C5_pUg  sukhothai-thai-restaurant-express-san-antonio-5
# 18  PyEIPJnZg-Y1NuNlWlsPEw                             singhs-san-antonio-2
# 19  X6btex-ZPuCq6zi6zKMFZA      wah-kee-chinese-seafood-cuisine-san-antonio
#
#                                  name  \
# 0                       Sichuan House
# 1                               Noods
# 2             Tiger’s Chinese Cuisine
# 3                 T Jin's China Diner
# 4              Tong's Thai Restaurant
# 5               Best Quality Daughter
# 6        Shinko- Hibachi and Boba Tea
# 7                               Katii
# 8                              Bamboo
# 9                              Ming's
# 10                          China Inn
# 11                          Time to 8
# 12                           Thai Dee
# 13                     Sichuan Garden
# 14       Ichiban Steak & Asian Fusion
# 15                       Lucky Noodle
# 16                     Formosa Garden
# 17  Sukhothai Thai Restaurant Express
# 18                             Singhs
# 19    Wah Kee Chinese Seafood Cuisine
#
#                                             image_url  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/ag1Cip...      False
# 1   https://s3-media4.fl.yelpcdn.com/bphoto/3AZnMJ...      False
# 2   https://s3-media1.fl.yelpcdn.com/bphoto/onJixH...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/MdxNjM...      False
# 4   https://s3-media4.fl.yelpcdn.com/bphoto/QASd7c...      False
# 5   https://s3-media2.fl.yelpcdn.com/bphoto/8IL8yk...      False
# 6   https://s3-media1.fl.yelpcdn.com/bphoto/YuY_UQ...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/yaeF9K...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/WZ7mdO...      False
# 9   https://s3-media1.fl.yelpcdn.com/bphoto/1LR8cZ...      False
# 10  https://s3-media2.fl.yelpcdn.com/bphoto/irs8xW...      False
# 11  https://s3-media4.fl.yelpcdn.com/bphoto/GqwHJ3...      False
# 12  https://s3-media1.fl.yelpcdn.com/bphoto/nf7-Hx...      False
# 13  https://s3-media4.fl.yelpcdn.com/bphoto/CSiQvq...      False
# 14  https://s3-media1.fl.yelpcdn.com/bphoto/U3068o...      False
# 15  https://s3-media1.fl.yelpcdn.com/bphoto/qcJTbV...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/y4Glxu...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/y9Mg-R...      False
# 18  https://s3-media3.fl.yelpcdn.com/bphoto/K-n1sd...      False
# 19  https://s3-media3.fl.yelpcdn.com/bphoto/U-yc2q...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/sichuan-house-san-ant...          1038
# 1   https://www.yelp.com/biz/noods-san-antonio-4?a...             7
# 2   https://www.yelp.com/biz/tiger-s-chinese-cuisi...           126
# 3   https://www.yelp.com/biz/t-jins-china-diner-sa...           412
# 4   https://www.yelp.com/biz/tongs-thai-restaurant...           852
# 5   https://www.yelp.com/biz/best-quality-daughter...           615
# 6   https://www.yelp.com/biz/shinko-hibachi-and-bo...            65
# 7   https://www.yelp.com/biz/katii-san-antonio?adj...            40
# 8   https://www.yelp.com/biz/bamboo-san-antonio-2?...           287
# 9   https://www.yelp.com/biz/mings-san-antonio?adj...           296
# 10  https://www.yelp.com/biz/china-inn-san-antonio...           411
# 11  https://www.yelp.com/biz/time-to-8-san-antonio...            94
# 12  https://www.yelp.com/biz/thai-dee-san-antonio?...           607
# 13  https://www.yelp.com/biz/sichuan-garden-san-an...           448
# 14  https://www.yelp.com/biz/ichiban-steak-and-asi...           240
# 15  https://www.yelp.com/biz/lucky-noodle-san-anto...           578
# 16  https://www.yelp.com/biz/formosa-garden-san-an...           350
# 17  https://www.yelp.com/biz/sukhothai-thai-restau...           185
# 18  https://www.yelp.com/biz/singhs-san-antonio-2?...           305
# 19  https://www.yelp.com/biz/wah-kee-chinese-seafo...           277
#
#                                            categories  rating  \
# 0   [{'alias': 'szechuan', 'title': 'Szechuan'}, {...     4.5
# 1   [{'alias': 'foodtrucks', 'title': 'Food Trucks...     4.5
# 2        [{'alias': 'szechuan', 'title': 'Szechuan'}]     4.0
# 3          [{'alias': 'chinese', 'title': 'Chinese'}]     4.5
# 4   [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.0
# 5   [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.5
# 6   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 7   [{'alias': 'foodtrucks', 'title': 'Food Trucks...     4.5
# 8   [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     3.5
# 9   [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.5
# 10         [{'alias': 'chinese', 'title': 'Chinese'}]     4.5
# 11  [{'alias': 'ramen', 'title': 'Ramen'}, {'alias...     3.0
# 12  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.0
# 13  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.5
# 14  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 15  [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.0
# 16  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     3.5
# 17  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.5
# 18   [{'alias': 'vietnamese', 'title': 'Vietnamese'}]     4.0
# 19  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     3.5
#
#                                           coordinates        transactions  \
# 0    {'latitude': 29.471805, 'longitude': -98.623466}  [delivery, pickup]
# 1   {'latitude': 29.44196636184658, 'longitude': -...                  []
# 2   {'latitude': 29.56257943164515, 'longitude': -...  [delivery, pickup]
# 3       {'latitude': 29.6388, 'longitude': -98.45705}  [delivery, pickup]
# 4   {'latitude': 29.4867884, 'longitude': -98.448251}  [delivery, pickup]
# 5     {'latitude': 29.44148, 'longitude': -98.479169}          [delivery]
# 6   {'latitude': 29.507840031658407, 'longitude': ...  [delivery, pickup]
# 7      {'latitude': 29.45053, 'longitude': -98.48654}          [delivery]
# 8   {'latitude': 29.41374873843138, 'longitude': -...  [delivery, pickup]
# 9   {'latitude': 29.440935621594612, 'longitude': ...  [delivery, pickup]
# 10  {'latitude': 29.535501215577124, 'longitude': ...          [delivery]
# 11     {'latitude': 29.52997, 'longitude': -98.59286}  [delivery, pickup]
# 12     {'latitude': 29.49933, 'longitude': -98.50813}  [delivery, pickup]
# 13  {'latitude': 29.5431364, 'longitude': -98.5285...            [pickup]
# 14     {'latitude': 29.51995, 'longitude': -98.60434}  [delivery, pickup]
# 15   {'latitude': 29.544727, 'longitude': -98.509676}          [delivery]
# 16     {'latitude': 29.51696, 'longitude': -98.45801}  [delivery, pickup]
# 17     {'latitude': 29.51146, 'longitude': -98.66207}  [delivery, pickup]
# 18  {'latitude': 29.451392717586, 'longitude': -98...          [delivery]
# 19  {'latitude': 29.611186284576338, 'longitude': ...  [delivery, pickup]
#
#    price                                           location         phone  \
# 0     $$  {'address1': '3505 Wurzbach Rd', 'address2': '...  +12105099999
# 1    NaN  {'address1': '427 Lombrano St', 'address2': No...  +12104800561
# 2     $$  {'address1': '12730 W I-10 Frontage Rd', 'addr...  +12105385080
# 3     $$  {'address1': '20835 US-281 N', 'address2': 'St...  +12105457777
# 4     $$  {'address1': '1146 Austin Hwy', 'address2': ''...  +12108297345
# 5     $$  {'address1': '602 Avenue A', 'address2': '', '...  +12108194236
# 6    NaN  {'address1': '7531 Bandera Rd', 'address2': 'S...  +12102908182
# 7      $  {'address1': '2710 N St Mary's St', 'address2'...  +18302605011
# 8      $  {'address1': '1010 S Flores St', 'address2': '...  +12104814884
# 9     $$  {'address1': '914 E Elmira St', 'address2': 'S...  +12106004083
# 10    $$  {'address1': '2241 NW Military Hwy', 'address2...  +12103088277
# 11    $$  {'address1': '9390 Huebner Rd', 'address2': 'S...  +17262156688
# 12    $$  {'address1': '5307 Blanco Rd', 'address2': '',...
# 13    $$  {'address1': '2347 NW Military Hwy', 'address2...  +12102655750
# 14    $$  {'address1': '8601 Huebner Rd', 'address2': 'S...  +12106411234
# 15    $$  {'address1': '8525 Blanco Rd', 'address2': '',...  +12102365244
# 16    $$  {'address1': '1011 NE Interstate 410 Loop', 'a...  +12108289988
# 17    $$  {'address1': '7664 Tezel Rd', 'address2': 'Ste...  +12103141106
# 18    $$  {'address1': '2803 N St Mary's St', 'address2'...
# 19     $  {'address1': '18360 Blanco Rd', 'address2': 'S...  +12104976669
#
#      display_phone      distance
# 0   (210) 509-9999  10858.688244
# 1   (210) 480-0561   5846.371498
# 2   (210) 538-5080  10740.456559
# 3   (210) 545-7777  16984.558552
# 4   (210) 829-7345   6469.028248
# 5   (210) 819-4236   6806.232818
# 6   (210) 290-8182  11279.128771
# 7   (830) 260-5011   5574.027946
# 8   (210) 481-4884   9086.260135
# 9   (210) 600-4083   6582.035891
# 10  (210) 308-8277   4648.029205
# 11  (726) 215-6688   8561.177724
# 12                    811.199667
# 13  (210) 265-5750   5635.678157
# 14  (210) 641-1234   9154.664067
# 15  (210) 236-5244   5610.526317
# 16  (210) 828-9988   6008.028225
# 17  (210) 314-1106  14414.083065
# 18                   5511.644718
# 19  (210) 497-6669  13001.938041

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 25

# %%
for i in tqdm_notebook(range(1,n_pages+1)):
    ## The block of code we want to TRY to run
    try:
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        ## save number of results to use as offset
        n_results = len(previous_results)
        
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(location = location, term = term,
                                   offset = n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])
        
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)

            
    ## What to do if we get an error/exception.
    except Exception as e:
        print(' [!] ERROR', e)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
df = pd.read_json(JSON_FILE)

# %%
df.head()
# Out:
#                        id                                alias  \
# 0  SqhBl2SvdGzRbWTiCMKR4A                  noods-san-antonio-4
# 1  hKSwFoVXwr9SpeiH6Na29A  tiger-s-chinese-cuisine-san-antonio
# 2  HNOz4-MhYCWNX2ik9UqYQw       t-jins-china-diner-san-antonio
# 3  vCXT8MFy4U8pW0ZmgoM9Xg    tongs-thai-restaurant-san-antonio
# 4  JYA-I2HxlqJxgArkKtSeuw    best-quality-daughter-san-antonio
#
#                       name                                          image_url  \
# 0                    Noods  https://s3-media4.fl.yelpcdn.com/bphoto/3AZnMJ...
# 1  Tiger’s Chinese Cuisine  https://s3-media1.fl.yelpcdn.com/bphoto/onJixH...
# 2      T Jin's China Diner  https://s3-media3.fl.yelpcdn.com/bphoto/MdxNjM...
# 3   Tong's Thai Restaurant  https://s3-media4.fl.yelpcdn.com/bphoto/QASd7c...
# 4    Best Quality Daughter  https://s3-media2.fl.yelpcdn.com/bphoto/8IL8yk...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/noods-san-antonio-4?a...             7
# 1      False  https://www.yelp.com/biz/tiger-s-chinese-cuisi...           126
# 2      False  https://www.yelp.com/biz/t-jins-china-diner-sa...           412
# 3      False  https://www.yelp.com/biz/tongs-thai-restaurant...           852
# 4      False  https://www.yelp.com/biz/best-quality-daughter...           615
#
#                                           categories  rating  \
# 0  [{'alias': 'foodtrucks', 'title': 'Food Trucks...     4.5
# 1       [{'alias': 'szechuan', 'title': 'Szechuan'}]     4.0
# 2         [{'alias': 'chinese', 'title': 'Chinese'}]     4.5
# 3  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.0
# 4  [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.5
#
#                                          coordinates        transactions  \
# 0  {'latitude': 29.44196636184658, 'longitude': -...                  []
# 1  {'latitude': 29.56257943164515, 'longitude': -...  [delivery, pickup]
# 2      {'latitude': 29.6388, 'longitude': -98.45705}  [delivery, pickup]
# 3  {'latitude': 29.4867884, 'longitude': -98.448251}  [delivery, pickup]
# 4    {'latitude': 29.44148, 'longitude': -98.479169}          [delivery]
#
#                                             location         phone  \
# 0  {'address1': '427 Lombrano St', 'address2': No...  +12104800561
# 1  {'address1': '12730 W I-10 Frontage Rd', 'addr...  +12105385080
# 2  {'address1': '20835 US-281 N', 'address2': 'St...  +12105457777
# 3  {'address1': '1146 Austin Hwy', 'address2': ''...  +12108297345
# 4  {'address1': '602 Avenue A', 'address2': '', '...  +12108194236
#
#     display_phone      distance price
# 0  (210) 480-0561   5846.371498   NaN
# 1  (210) 538-5080  10740.456559    $$
# 2  (210) 545-7777  16984.558552    $$
# 3  (210) 829-7345   6469.028248    $$
# 4  (210) 819-4236   6806.232818    $$

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/San antonio, TX .csv.gz'
